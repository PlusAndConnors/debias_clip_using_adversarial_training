# %%
from PIL import Image
from tqdm.auto import tqdm
from transformers import CLIPTextModel, CLIPTokenizer, AdamW
from diffusers import AutoencoderKL, UNet2DConditionModel
from diffusers import LMSDiscreteScheduler

import torch
import torch.nn.functional as F
import argparse
import os
from generation_utils import debias_vl_set, txt_process, bias_prompt, AttackTarget
from copy import deepcopy as dc

# %%
class Args:
    cls = "a photo of a waterbird"  # target class name
    lam = 100.0  # regularizer constant
    mode = "base"  # mode options: ['debias_vl', 'base', 'debias_vl_bias']
    use = "base"  # use options: ['debias_vl', 'base', 'fairerclip']
    revision = None  # Revision of pretrained model identifier from huggingface.co/models
    bias = "background"  # Bias type
    epochs = 100  # Number of epochs
    alpha = 0.3  # Alpha value
    pretrained_model_name_or_path = "stabilityai/stable-diffusion-2-1-base"  # Path to pretrained model
    config_file = "configs/debias_waterbird_mode.yaml"  # Path to config file
    model = "clip_ViTL14"  # Model type
    pretrained_vae_name_or_path = None  # Path to pretrained VAE

# Instantiate args
args = Args()

# %%
torch_device = "cuda" if torch.cuda.is_available() else "cpu"
height = 512  # default height of Stable Diffusion
width = 512  # default width of Stable Diffusion
num_inference_steps = 100  # Number of denoising steps
guidance_scale = 7.5  # Scale for classifier-free guidance
batch_size = 1
alpha = 0.3
pretrained_model_name_or_path = "stabilityai/stable-diffusion-2-1-base"
tokenizer = CLIPTokenizer.from_pretrained(pretrained_model_name_or_path, subfolder="tokenizer" )
text_encoder = CLIPTextModel.from_pretrained(pretrained_model_name_or_path, subfolder="text_encoder" )
text_encoder = text_encoder.to(torch_device)

target_model = AttackTarget(text_encoder, 1, torch_device).to(torch_device)
optimizer = AdamW(filter(lambda p: p.requires_grad, target_model.parameters()), lr=5e-5)
# peft tuning
sub = torch.tensor(0, device=torch_device).float()

candidate_prompt, S = debias_vl_set(args)
bias_prompt, S_bias = bias_prompt(two_prompt=False)
retain_prompt = ['a photo of a landbird.', 'a photo of a waterbird.']
cls_step = len(S) // len(retain_prompt)
# Out:
# /home/connor/.conda/envs/fair/lib/python3.9/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/connor/.conda/envs/fair/lib/python3.9/site-packages/transformers/optimization.py:521: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
with torch.no_grad():
    z0 = txt_process(retain_prompt, text_encoder, tokenizer, torch_device)
    z_diff = txt_process(candidate_prompt, text_encoder, tokenizer, torch_device)
    z_diff_bias = txt_process(bias_prompt, text_encoder, tokenizer, torch_device)
candidate_set = {
    idx: tokenizer(text=candidate_prompt[idx], padding='max_length', return_tensors="pt", truncation=True).to(
        torch_device) for idx in range(len(candidate_prompt))
}
use_ = 'bias'


def create_attention_mask(input_shape):
    # Create a causal attention mask for CLIP
    batch_size, seq_len = input_shape
    mask = torch.full((batch_size, 1, seq_len, seq_len), float("-inf"))
    mask = torch.triu(mask, diagonal=1)
    mask = mask.to('cuda' if torch.cuda.is_available() else 'cpu')
    return mask


with torch.no_grad():
    token_, ret_mask = target_model.tokenizer(tokenizer, retain_prompt)
    check_ = token_['input_ids'].argmax(-1)
    wz_feature = target_model.get_feature(token_.input_ids, ret_mask)
    candi_token_, cand_mask = target_model.tokenizer(tokenizer, candidate_prompt)
    z_diff_feature = target_model.get_feature(candi_token_.input_ids, cand_mask)
    bias_token_, bias_mask = target_model.tokenizer(tokenizer, bias_prompt)
    z_diff_bias_feature = target_model.get_feature(bias_token_.input_ids, bias_mask)

target_len, token_len, dim = z0.shape
mix_len, bias_len = z_diff.size(0), z_diff_bias.size(0)
ind_target, ind_bias, ind_mix = token_['input_ids'], bias_token_['input_ids'], candi_token_['input_ids']
z0_tar_eos = F.normalize(z0[torch.arange(target_len), ind_target.argmax(-1)], dim=-1)
z0_mix_eos = F.normalize(z_diff[torch.arange(z_diff.shape[0]), candi_token_['input_ids'].argmax(-1)], dim=-1)
z0_bias_eos = F.normalize(z_diff_bias[torch.arange(z_diff_bias.shape[0]), bias_token_['input_ids'].argmax(-1)],
                          dim=-1)
min_value = z0_tar_eos[0].detach() @ z0_tar_eos[1].detach().T

ind_ = torch.eye(7, dtype=torch.bool)
ind_2 = torch.cat([torch.eye(7, dtype=torch.bool), torch.eye(7, dtype=torch.bool)])
indices_1 = torch.tensor([[1] * 7 + [0] * 7, [0] * 7 + [0] * 7], device=torch_device, dtype=torch.bool)
indices_2 = torch.tensor([[0] * 7 + [0] * 7, [0] * 7 + [1] * 7], device=torch_device, dtype=torch.bool)
indices_3 = torch.tensor([[0] * 7 + [1] * 7, [1] * 7 + [0] * 7], device=torch_device, dtype=torch.bool)

# mix - mix

sim_mix0_mix0_right = (z0_mix_eos[:7] @ z0_mix_eos[7:].T)[ind_]
sim_mix0_mix0_wrong = (z0_mix_eos[:7] @ z0_mix_eos[7:].T)[~ind_]
# tar - mix
sim_tar0_mix0 = (z0_tar_eos @ z0_mix_eos.T)
sim_tar0_mix0_right = sim_tar0_mix0[~indices_3]
sim_tar0_mix0_wrong = sim_tar0_mix0[indices_3]
# bias
sim_tar0_bias0 = z0_tar_eos @ z0_bias_eos.T
# mix - bias
sim_mix0_bias0 = (z0_mix_eos @ z0_bias_eos.T)
sim_mix0_bias0_right = sim_mix0_bias0[ind_2]
sim_mix0_bias0_wrong = sim_mix0_bias0[~ind_2]
a_0, a_1 = sim_mix0_bias0_right.split(7)
sim_new_type = ((z0_mix_eos @ z0_bias_eos.T)[ind_2] + min_value) / 2
right_min = torch.cat([sim_tar0_mix0_right, sim_mix0_mix0_right]).min()
wrong_max = torch.cat([sim_tar0_mix0_wrong, sim_mix0_mix0_wrong]).max()
print(f'ck_list : mix_r {int(sim_mix0_mix0_right.mean() * 100)}, w {int(sim_mix0_mix0_wrong.mean() * 100)}'
      f'| tar_mix_r {int(sim_tar0_mix0_right.mean() * 100)}, w {int(sim_tar0_mix0_wrong.mean() * 100)}'
      f'| mix_bias_r {int(sim_mix0_bias0_right.mean() * 100)}, w {int(sim_mix0_bias0_wrong.mean() * 100)}'
      f'| tar_bias {int(sim_tar0_bias0.mean() * 100)}')

sim_mix0_mix0 = z0_mix_eos @ z0_mix_eos.T
ind_ = torch.eye(7, dtype=torch.bool)
first_class_indices = torch.triu_indices(7, 7, 1)
first_class_indices2 = torch.triu_indices(7, 7, 1) + 7
first_class_similarity =  torch.cat([sim_mix0_mix0[first_class_indices[0], first_class_indices[1]], sim_mix0_mix0[first_class_indices2[0], first_class_indices2[1]],sim_mix0_mix0[first_class_indices[1], first_class_indices[0]], sim_mix0_mix0[first_class_indices2[1], first_class_indices2[0]]])

second_class_indices = (torch.arange(7), torch.arange(7) + 7)
second_class_similarity = torch.cat([sim_mix0_mix0[second_class_indices[0], second_class_indices[1]],sim_mix0_mix0[second_class_indices[1], second_class_indices[0]]])
other_similarity_mask = ~torch.eye(14, dtype=torch.bool) & ~(torch.triu(torch.ones(14, 14), 1).bool())
other_similarity = sim_mix0_mix0[other_similarity_mask]
# Out:
# ck_list : mix_r 86, w 69| tar_mix_r 67, w 53| mix_bias_r 56, w 40| tar_bias 33
# /tmp/ipykernel_1611208/1741191970.py:37: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343964576/work/aten/src/ATen/native/TensorShape.cpp:3571.)
#   min_value = z0_tar_eos[0].detach() @ z0_tar_eos[1].detach().T

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors

norm = mcolors.TwoSlopeNorm(vmin=0.2, vcenter=0.4, vmax=0.6)
plt.imshow(sim_tar0_bias0.cpu().detach().numpy(), interpolation='nearest', cmap=plt.cm.Blues, norm=norm)
for (i, j), val in np.ndenumerate(sim_tar0_bias0.cpu()):
    if val != 0:
        plt.text(j, i, f'{val:.2f}', ha='center', va='center', color='black', fontsize=8)
plt.colorbar()

plt.title('Confusion Matrix')
plt.xlabel('Bias Prompt')
plt.ylabel('Target Prompt')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

norm = mcolors.TwoSlopeNorm(vmin=0.2, vcenter=0.4, vmax=0.6)
plt.imshow(sim_mix0_bias0.cpu().detach().numpy(), interpolation='nearest', cmap=plt.cm.Blues, norm=norm)
for (i, j), val in np.ndenumerate(sim_mix0_bias0.cpu()):
    if val != 0:
        plt.text(j, i, f'{val:.2f}', ha='center', va='center', color='black', fontsize=8)
plt.colorbar()

plt.title('mix&bias')
plt.xlabel('bias')
plt.ylabel('mix')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

norm = mcolors.TwoSlopeNorm(vmin=0.5, vcenter=0.65, vmax=0.8)
plt.imshow(sim_tar0_mix0.cpu().detach().numpy(), interpolation='nearest', cmap=plt.cm.Blues, norm=norm)
for (i, j), val in np.ndenumerate(sim_tar0_mix0.cpu()):
    if val != 0:
        plt.text(j, i, f'{val:.2f}', ha='center', va='center', color='black', fontsize=8)
plt.colorbar()

plt.title('cosin with tar and mix')
plt.xlabel('mix')
plt.ylabel('tar')
plt.show()

# %%
first_class_indices =  torch.cat([torch.triu_indices(7, 7, 1),torch.triu_indices(7, 7, 1) + 7],dim=1)
first_class_similarity = torch.cat([
    sim_mix0_mix0[first_class_indices[0], first_class_indices[1]],
    sim_mix0_mix0[first_class_indices[1], first_class_indices[0]],
])

second_class_indices = (torch.arange(7), torch.arange(7) + 7)
second_class_similarity = torch.cat([
    sim_mix0_mix0[second_class_indices[0], second_class_indices[1]],
    sim_mix0_mix0[second_class_indices[1], second_class_indices[0]]
])

# 모든 인덱스 쌍 추출
all_indices = torch.triu_indices(14, 14, 1)
all_pairs = set(zip(all_indices[0].tolist(), all_indices[1].tolist())) | set(zip(all_indices[1].tolist(), all_indices[0].tolist()))

# 첫 번째 클래스나 두 번째 클래스에 속하지 않는 인덱스 추출
excluded_indices = set(zip(first_class_indices[0].tolist(), first_class_indices[1].tolist())) | \
                   set(zip(first_class_indices[1].tolist(), first_class_indices[0].tolist())) | \
                   set(zip(second_class_indices[0].tolist(), second_class_indices[1].tolist())) | \
                   set(zip(torch.arange(14).tolist(), torch.arange(14).tolist())) | \
                   set(zip(second_class_indices[1].tolist(), second_class_indices[0].tolist()))


# 나머지 인덱스들을 필터링하여 추출 (대각선 요소도 포함)
other_pairs = all_pairs - excluded_indices
other_indices = (torch.tensor([i for i, j in other_pairs]), torch.tensor([j for i, j in other_pairs]))

# 나머지 인덱스들의 유사도 추출
other_similarity = sim_mix0_mix0[other_indices[0], other_indices[1]]

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors
import matplotlib.patches as patches

# 임의의 유사도 행렬 생성 (가상의 데이터로 예시)
sim_mix0_mix0 = z0_mix_eos @ z0_mix_eos.T

# 첫 번째 클래스가 같은 항들의 유사도 추출
first_class_indices =  torch.cat([torch.triu_indices(7, 7, 1),torch.triu_indices(7, 7, 1) + 7],dim=1)
first_class_similarity = torch.cat([
    sim_mix0_mix0[first_class_indices[0], first_class_indices[1]],
    sim_mix0_mix0[first_class_indices[1], first_class_indices[0]],
])

# 두 번째 클래스가 같은 항들의 유사도 추출
second_class_indices = (torch.arange(7), torch.arange(7) + 7)
second_class_similarity = torch.cat([
    sim_mix0_mix0[second_class_indices[0], second_class_indices[1]],
    sim_mix0_mix0[second_class_indices[1], second_class_indices[0]]
])

# Confusion Matrix 초기화
confusion_matrix = torch.zeros(14, 14).to(torch_device)

# 첫 번째 클래스 유사도 값 반영
confusion_matrix[first_class_indices[0], first_class_indices[1]] = first_class_similarity[:len(first_class_similarity)//2]
confusion_matrix[first_class_indices[1], first_class_indices[0]] = first_class_similarity[len(first_class_similarity)//2:]

# 두 번째 클래스 유사도 값 반영
confusion_matrix[second_class_indices[0], second_class_indices[1]] = second_class_similarity[:len(second_class_similarity)//2]
confusion_matrix[second_class_indices[1], second_class_indices[0]] = second_class_similarity[len(second_class_similarity)//2:]

all_indices = torch.triu_indices(14, 14, 1)
all_pairs = set(zip(all_indices[0].tolist(), all_indices[1].tolist())) | set(zip(all_indices[1].tolist(), all_indices[0].tolist()))

# 첫 번째 클래스나 두 번째 클래스에 속하지 않는 인덱스 추출
excluded_indices = set(zip(first_class_indices[0].tolist(), first_class_indices[1].tolist())) | \
                   set(zip(first_class_indices[1].tolist(), first_class_indices[0].tolist())) | \
                   set(zip(second_class_indices[0].tolist(), second_class_indices[1].tolist())) | \
                   set(zip(torch.arange(14).tolist(), torch.arange(14).tolist())) | \
                   set(zip(second_class_indices[1].tolist(), second_class_indices[0].tolist()))


# 나머지 인덱스들을 필터링하여 추출 (대각선 요소도 포함)
other_pairs = all_pairs - excluded_indices
other_indices = (torch.tensor([i for i, j in other_pairs]), torch.tensor([j for i, j in other_pairs]))

# 나머지 인덱스들의 유사도 추출
other_similarity = sim_mix0_mix0[other_indices[0], other_indices[1]]
confusion_matrix[other_indices[0], other_indices[1]] = other_similarity
confusion_matrix[other_indices[1], other_indices[0]] = other_similarity


# 시각화
norm = mcolors.TwoSlopeNorm(vmin=0.6, vcenter=0.8, vmax=0.9)
plt.figure(figsize=(8, 8))
plt.imshow(confusion_matrix.cpu(), cmap='Blues', interpolation='nearest', norm=norm)

# 첫 번째 클래스 영역에 테두리 추가
for i, j in zip(first_class_indices[0].cpu().numpy(), first_class_indices[1].cpu().numpy()):
    rect = patches.Rectangle((j - 0.5, i - 0.5), 1, 1, linewidth=1, edgecolor='red', facecolor='none')
    plt.gca().add_patch(rect)
for i, j in zip(first_class_indices[1].cpu().numpy(), first_class_indices[0].cpu().numpy()):
    rect = patches.Rectangle((j - 0.5, i - 0.5), 1, 1, linewidth=1, edgecolor='red', facecolor='none')
    plt.gca().add_patch(rect)


# 두 번째 클래스 영역에 테두리 추가
for i, j in zip(second_class_indices[0].cpu().numpy(), second_class_indices[1].cpu().numpy()):
    rect = patches.Rectangle((j - 0.5, i - 0.5), 1, 1, linewidth=1.5, edgecolor='green', facecolor='none')
    plt.gca().add_patch(rect)
for i, j in zip(second_class_indices[1].cpu().numpy(), second_class_indices[0].cpu().numpy()):
    rect = patches.Rectangle((j - 0.5, i - 0.5), 1, 1, linewidth=1.5, edgecolor='green', facecolor='none')
    plt.gca().add_patch(rect)


# Add color bar with labels
cbar = plt.colorbar()
cbar.set_label('Similarity', fontsize=12)

# Annotate matrix with values
for (i, j), val in np.ndenumerate(confusion_matrix.cpu()):
    if val != 0:
        plt.text(j, i, f'{val:.2f}', ha='center', va='center', color='black', fontsize=8)

plt.title('Confusion Matrix with First and Second Class Similarity', fontsize=12, weight='bold')
plt.xlabel('Index', fontsize=14)
plt.ylabel('Index', fontsize=14)
plt.grid(False)

# Display the plot
plt.show()

# %%
candidate_prompt
# Out:
# ['a photo of a landbird with land background',
#  'a photo of a landbird with wood background',
#  'a photo of a landbird with forest background',
#  'a photo of a landbird with mountain background',
#  'a photo of a landbird with water background',
#  'a photo of a landbird with ocean background',
#  'a photo of a landbird with beach background',
#  'a photo of a waterbird with land background',
#  'a photo of a waterbird with wood background',
#  'a photo of a waterbird with forest background',
#  'a photo of a waterbird with mountain background',
#  'a photo of a waterbird with water background',
#  'a photo of a waterbird with ocean background',
#  'a photo of a waterbird with beach background']

# %%
first_class_similarity_0 = torch.cat([
    sim_mix0_mix0[first_class_indices[0], first_class_indices[1]],
    sim_mix0_mix0[first_class_indices[1], first_class_indices[0]],
])
second_class_similarity_0 = torch.cat([
    sim_mix0_mix0[second_class_indices[0], second_class_indices[1]],
    sim_mix0_mix0[second_class_indices[1], second_class_indices[0]]
])
other_similarity_0 = sim_mix0_mix0[other_indices[0], other_indices[1]]
balancing = len(first_class_similarity_0)/ len(second_class_similarity_0)

# %%
rows = len(retain_prompt)
cols = int(len(S)/rows)
list_2d = [S[i * cols:(i + 1) * cols] for i in range(rows)]

# %%
for epoch in range(100):  # Number of epochs
    equalization_loss, distil_loss, target_loss = dc(sub), dc(sub), dc(sub)
    upper_loss, balance, match3 = dc(sub), dc(sub), dc(sub)
    optimizer.zero_grad()

    z_tar = target_model(wz_feature)
    z_mix = target_model(z_diff_feature)
    for wz_, z0_ in zip(z_tar, z0):
        distil_loss += F.mse_loss(wz_, z0_).to(torch_device)

    z_tar_eos = F.normalize(z_tar[torch.arange(z_tar.shape[0]), check_], dim=-1)
    z_mix_eos = F.normalize(z_mix[torch.arange(z_mix.shape[0]), ind_mix.argmax(-1)], dim=-1)

    # mix - mix
    sim_mix_mix_right = (z_mix_eos[:7] @ z_mix_eos[7:].T)[ind_]
    sim_mix0_mix0_wrong = (z_mix_eos[:7] @ z_mix_eos[7:].T)[~ind_]
    # tar - mix
    sim_tar_mix = (z_tar_eos @ z_mix_eos.T)
    sim_tar0_mix0_right = sim_tar_mix[~indices_3]
    sim_tar0_mix0_wrong = sim_tar_mix[indices_3]
    # bias
    sim_tar_bias0 = z_tar_eos @ z0_bias_eos.T
    # mix -sim_mix0_bias0 bias
    sim_mix_bias0 = (z_mix_eos @ z0_bias_eos.T)
    sim_mix0_bias0sim_mix0_bias0_right = sim_mix_bias0[ind_2]
    sim_mix0_bias0_wrong = sim_mix_bias0[~ind_2]

    # print(f'ck_list : mix_r {int(sim_mix_mix_right.mean() * 100)}, w {int(sim_mix0_mix0_wrong.mean() * 100)}'
    #       f'| tar_mix_r {int(sim_tar0_mix0_right.mean() * 100)}, w {int(sim_tar0_mix0_wrong.mean() * 100)}'
    #       f'| mix_bias_r {int(sim_mix0_bias0_right.mean() * 100)}, w {int(sim_mix0_bias0_wrong.mean() * 100)}'
    #       f'| tar_bias {int(sim_tar0_bias0.mean() * 100)}')
    
    sim_mix_mix0 = z_mix_eos @ z0_mix_eos.T

    first_class_similarity = torch.cat([
        sim_mix_mix0[first_class_indices[0], first_class_indices[1]],
        sim_mix_mix0[first_class_indices[1], first_class_indices[0]],
    ])
    second_class_similarity = torch.cat([
        sim_mix_mix0[second_class_indices[0], second_class_indices[1]],
        sim_mix_mix0[second_class_indices[1], second_class_indices[0]]
    ])
    other_similarity = sim_mix_mix0[other_indices[0], other_indices[1]]

    other_loss = torch.relu(other_similarity - other_similarity_0.min()).mean()
    balance += torch.mean((first_class_similarity - first_class_similarity_0.mean()) ** 2) 
    balance += torch.mean((second_class_similarity - second_class_similarity_0.mean()) ** 2)
    # upper_loss += torch.relu(first_class_similarity_0.max() - first_class_similarity.mean())
    # upper_loss += torch.relu(second_class_similarity_0.max() - second_class_similarity.mean())
    
    # sim_tar_mix0 = (z_tar_eos @ z0_mix_eos.T)
    # sim_tar_bias0 = (z_tar_eos @ z0_bias_eos.T)
    # sim_mix_bias0_0 = (z_mix_eos[:7] @ z0_bias_eos.T)
    # sim_mix_bias0_1 = (z_mix_eos[7:] @ z0_bias_eos.T)
    # sim_mix_mix = (z_mix_eos[:7] @ z_mix_eos[7:].T)
    # match = torch.relu(sim_mix_bias0_0[~ind_].max() - sim_mix_bias0_0[ind_].min() + 0.1) + torch.relu(
    #     sim_mix_bias0_1[~ind_].max() - sim_mix_bias0_1[ind_].min() + 0.1) + torch.relu(
    #     sim_mix_mix[~ind_].max() - sim_mix_mix[ind_].min() + 0.1)
    # match2 = torch.relu(sim_tar_mix0[indices_3].max() - sim_tar_mix0[indices_1].min() + 0.1) + torch.relu(
    #     sim_tar_mix0[indices_3].max() - sim_tar_mix0[indices_2].min() + 0.1)


    
    match3 = other_loss + balance * 5 # + match + match2 # + upper_loss * 10

    print(f'{epoch}epoch |' 'other_loss : ', round(other_loss.item(), 4), 
          'balance : ', round(balance.item(), 4),
          'upper_loss : ', round(upper_loss.item(), 4))
    target_loss += match3

    loss = (1 - alpha) * distil_loss + alpha * target_loss
    loss.backward()
    optimizer.step()

target_model.eval()
# Out:
# 0epoch |other_loss :  0.0067 balance :  0.0304 upper_loss :  0.0
# 1epoch |other_loss :  0.015 balance :  0.0258 upper_loss :  0.0
# 2epoch |other_loss :  0.0295 balance :  0.0198 upper_loss :  0.0
# 3epoch |other_loss :  0.0456 balance :  0.0146 upper_loss :  0.0
# 4epoch |other_loss :  0.0588 balance :  0.0107 upper_loss :  0.0
# 5epoch |other_loss :  0.0682 balance :  0.0081 upper_loss :  0.0
# 6epoch |other_loss :  0.0738 balance :  0.0065 upper_loss :  0.0
# 7epoch |other_loss :  0.076 balance :  0.0055 upper_loss :  0.0
# 8epoch |other_loss :  0.0753 balance :  0.005 upper_loss :  0.0
# 9epoch |other_loss :  0.072 balance :  0.0049 upper_loss :  0.0
# 10epoch |other_loss :  0.0666 balance :  0.0052 upper_loss :  0.0
# 11epoch |other_loss :  0.0596 balance :  0.0059 upper_loss :  0.0
# 12epoch |other_loss :  0.0522 balance :  0.0069 upper_loss :  0.0
# 13epoch |other_loss :  0.0449 balance :  0.0082 upper_loss :  0.0
# 14epoch |other_loss :  0.0388 balance :  0.0094 upper_loss :  0.0
# 15epoch |other_loss :  0.0344 balance :  0.0103 upper_loss :  0.0
# 16epoch |other_loss :  0.032 balance :  0.0107 upper_loss :  0.0
# 17epoch |other_loss :  0.0313 balance :  0.0106 upper_loss :  0.0
# 18epoch |other_loss :  0.032 balance :  0.0101 upper_loss :  0.0
# 19epoch |other_loss :  0.0337 balance :  0.0094 upper_loss :  0.0
# 20epoch |other_loss :  0.036 balance :  0.0087 upper_loss :  0.0
# 21epoch |other_loss :  0.0383 balance :  0.0081 upper_loss :  0.0
# 22epoch |other_loss :  0.0403 balance :  0.0077 upper_loss :  0.0
# 23epoch |other_loss :  0.0413 balance :  0.0075 upper_loss :  0.0
# 24epoch |other_loss :  0.0409 balance :  0.0075 upper_loss :  0.0
# 25epoch |other_loss :  0.0393 balance :  0.0078 upper_loss :  0.0
# 26epoch |other_loss :  0.0369 balance :  0.0081 upper_loss :  0.0
# 27epoch |other_loss :  0.0343 balance :  0.0086 upper_loss :  0.0
# 28epoch |other_loss :  0.032 balance :  0.0089 upper_loss :  0.0
# 29epoch |other_loss :  0.0304 balance :  0.0092 upper_loss :  0.0
# 30epoch |other_loss :  0.0298 balance :  0.0093 upper_loss :  0.0
# 31epoch |other_loss :  0.0298 balance :  0.0092 upper_loss :  0.0
# 32epoch |other_loss :  0.0302 balance :  0.0091 upper_loss :  0.0
# 33epoch |other_loss :  0.0304 balance :  0.009 upper_loss :  0.0
# 34epoch |other_loss :  0.0305 balance :  0.0089 upper_loss :  0.0
# 35epoch |other_loss :  0.0307 balance :  0.0088 upper_loss :  0.0
# 36epoch |other_loss :  0.0312 balance :  0.0087 upper_loss :  0.0
# 37epoch |other_loss :  0.0318 balance :  0.0085 upper_loss :  0.0
# 38epoch |other_loss :  0.0322 balance :  0.0084 upper_loss :  0.0
# 39epoch |other_loss :  0.0321 balance :  0.0084 upper_loss :  0.0
# 40epoch |other_loss :  0.0315 balance :  0.0085 upper_loss :  0.0
# 41epoch |other_loss :  0.0307 balance :  0.0086 upper_loss :  0.0
# 42epoch |other_loss :  0.0302 balance :  0.0087 upper_loss :  0.0
# 43epoch |other_loss :  0.0298 balance :  0.0087 upper_loss :  0.0
# 44epoch |other_loss :  0.0298 balance :  0.0087 upper_loss :  0.0
# 45epoch |other_loss :  0.0298 balance :  0.0086 upper_loss :  0.0
# 46epoch |other_loss :  0.0301 balance :  0.0086 upper_loss :  0.0
# 47epoch |other_loss :  0.0301 balance :  0.0085 upper_loss :  0.0
# 48epoch |other_loss :  0.03 balance :  0.0085 upper_loss :  0.0
# 49epoch |other_loss :  0.0299 balance :  0.0085 upper_loss :  0.0
# 50epoch |other_loss :  0.03 balance :  0.0085 upper_loss :  0.0
# 51epoch |other_loss :  0.0298 balance :  0.0085 upper_loss :  0.0
# 52epoch |other_loss :  0.0296 balance :  0.0085 upper_loss :  0.0
# 53epoch |other_loss :  0.0294 balance :  0.0085 upper_loss :  0.0
# 54epoch |other_loss :  0.0293 balance :  0.0085 upper_loss :  0.0
# 55epoch |other_loss :  0.0293 balance :  0.0085 upper_loss :  0.0
# 56epoch |other_loss :  0.0294 balance :  0.0085 upper_loss :  0.0
# 57epoch |other_loss :  0.0293 balance :  0.0085 upper_loss :  0.0
# 58epoch |other_loss :  0.0293 balance :  0.0084 upper_loss :  0.0
# 59epoch |other_loss :  0.0291 balance :  0.0085 upper_loss :  0.0
# 60epoch |other_loss :  0.0289 balance :  0.0085 upper_loss :  0.0
# 61epoch |other_loss :  0.0287 balance :  0.0085 upper_loss :  0.0
# 62epoch |other_loss :  0.0287 balance :  0.0085 upper_loss :  0.0
# 63epoch |other_loss :  0.0289 balance :  0.0084 upper_loss :  0.0
# 64epoch |other_loss :  0.029 balance :  0.0084 upper_loss :  0.0
# 65epoch |other_loss :  0.0286 balance :  0.0085 upper_loss :  0.0
# 66epoch |other_loss :  0.0282 balance :  0.0085 upper_loss :  0.0
# 67epoch |other_loss :  0.0284 balance :  0.0085 upper_loss :  0.0
# 68epoch |other_loss :  0.0286 balance :  0.0084 upper_loss :  0.0
# 69epoch |other_loss :  0.0284 balance :  0.0084 upper_loss :  0.0
# 70epoch |other_loss :  0.0282 balance :  0.0084 upper_loss :  0.0
# 71epoch |other_loss :  0.0282 balance :  0.0084 upper_loss :  0.0
# 72epoch |other_loss :  0.0284 balance :  0.0084 upper_loss :  0.0
# 73epoch |other_loss :  0.0283 balance :  0.0084 upper_loss :  0.0
# 74epoch |other_loss :  0.028 balance :  0.0084 upper_loss :  0.0
# 75epoch |other_loss :  0.0282 balance :  0.0084 upper_loss :  0.0
# 76epoch |other_loss :  0.0282 balance :  0.0083 upper_loss :  0.0
# 77epoch |other_loss :  0.0282 balance :  0.0083 upper_loss :  0.0
# 78epoch |other_loss :  0.0282 balance :  0.0083 upper_loss :  0.0
# 79epoch |other_loss :  0.0282 balance :  0.0083 upper_loss :  0.0
# 80epoch |other_loss :  0.0283 balance :  0.0082 upper_loss :  0.0
# 81epoch |other_loss :  0.0285 balance :  0.0082 upper_loss :  0.0
# 82epoch |other_loss :  0.0282 balance :  0.0082 upper_loss :  0.0
# 83epoch |other_loss :  0.0277 balance :  0.0083 upper_loss :  0.0
# 84epoch |other_loss :  0.0278 balance :  0.0083 upper_loss :  0.0
# 85epoch |other_loss :  0.0283 balance :  0.0082 upper_loss :  0.0
# 86epoch |other_loss :  0.0283 balance :  0.0082 upper_loss :  0.0
# 87epoch |other_loss :  0.0277 balance :  0.0083 upper_loss :  0.0
# 88epoch |other_loss :  0.0276 balance :  0.0083 upper_loss :  0.0
# 89epoch |other_loss :  0.0281 balance :  0.0082 upper_loss :  0.0
# 90epoch |other_loss :  0.0284 balance :  0.0081 upper_loss :  0.0
# 91epoch |other_loss :  0.0279 balance :  0.0082 upper_loss :  0.0
# 92epoch |other_loss :  0.0272 balance :  0.0083 upper_loss :  0.0
# 93epoch |other_loss :  0.0271 balance :  0.0083 upper_loss :  0.0
# 94epoch |other_loss :  0.0274 balance :  0.0083 upper_loss :  0.0
# 95epoch |other_loss :  0.0276 balance :  0.0082 upper_loss :  0.0
# 96epoch |other_loss :  0.0275 balance :  0.0082 upper_loss :  0.0
# 97epoch |other_loss :  0.0273 balance :  0.0082 upper_loss :  0.0
# 98epoch |other_loss :  0.0272 balance :  0.0082 upper_loss :  0.0
# 99epoch |other_loss :  0.0276 balance :  0.0081 upper_loss :  0.0
# AttackTarget(
#   (text_encoder): CLIPTextModel(
#     (text_model): CLIPTextTransformer(
#       (embeddings): CLIPTextEmbeddings(
#         (token_embedding): Embedding(49408, 1024)
#         (position_embedding): Embedding(77, 1024)
#       )
#       (encoder): CLIPEncoder(
#         (layers): ModuleList(
#           (0-22): 23 x CLIPEncoderLayer(
#             (self_attn): CLIPAttention(
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (layer_norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (mlp): CLIPMLP(
#               (activation_fn): GELUActivation()
#               (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#               (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             )
#             (layer_norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
# )

# %%
target_loss
# Out:
# tensor(0.0683, device='cuda:0', grad_fn=<AddBackward0>)

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors
import matplotlib.patches as patches

# 임의의 유사도 행렬 생성 (가상의 데이터로 예시)
sim_mix0_mix0 = z_mix_eos @ z_mix_eos.T

# 첫 번째 클래스가 같은 항들의 유사도 추출
first_class_indices =  torch.cat([torch.triu_indices(7, 7, 1),torch.triu_indices(7, 7, 1) + 7],dim=1)
first_class_similarity = torch.cat([
    sim_mix0_mix0[first_class_indices[0], first_class_indices[1]],
    sim_mix0_mix0[first_class_indices[1], first_class_indices[0]],
])

# 두 번째 클래스가 같은 항들의 유사도 추출
second_class_indices = (torch.arange(7), torch.arange(7) + 7)
second_class_similarity = torch.cat([
    sim_mix0_mix0[second_class_indices[0], second_class_indices[1]],
    sim_mix0_mix0[second_class_indices[1], second_class_indices[0]]
])

# Confusion Matrix 초기화
confusion_matrix = torch.zeros(14, 14).to(torch_device)

# 첫 번째 클래스 유사도 값 반영
confusion_matrix[first_class_indices[0], first_class_indices[1]] = first_class_similarity[:len(first_class_similarity)//2]
confusion_matrix[first_class_indices[1], first_class_indices[0]] = first_class_similarity[len(first_class_similarity)//2:]

# 두 번째 클래스 유사도 값 반영
confusion_matrix[second_class_indices[0], second_class_indices[1]] = second_class_similarity[:len(second_class_similarity)//2]
confusion_matrix[second_class_indices[1], second_class_indices[0]] = second_class_similarity[len(second_class_similarity)//2:]

all_indices = torch.triu_indices(14, 14, 1)
all_pairs = set(zip(all_indices[0].tolist(), all_indices[1].tolist())) | set(zip(all_indices[1].tolist(), all_indices[0].tolist()))

# 첫 번째 클래스나 두 번째 클래스에 속하지 않는 인덱스 추출
excluded_indices = set(zip(first_class_indices[0].tolist(), first_class_indices[1].tolist())) | \
                   set(zip(first_class_indices[1].tolist(), first_class_indices[0].tolist())) | \
                   set(zip(second_class_indices[0].tolist(), second_class_indices[1].tolist())) | \
                   set(zip(torch.arange(14).tolist(), torch.arange(14).tolist())) | \
                   set(zip(second_class_indices[1].tolist(), second_class_indices[0].tolist()))


# 나머지 인덱스들을 필터링하여 추출 (대각선 요소도 포함)
other_pairs = all_pairs - excluded_indices
other_indices = (torch.tensor([i for i, j in other_pairs]), torch.tensor([j for i, j in other_pairs]))

# 나머지 인덱스들의 유사도 추출
other_similarity = sim_mix0_mix0[other_indices[0], other_indices[1]]
confusion_matrix[other_indices[0], other_indices[1]] = other_similarity
confusion_matrix[other_indices[1], other_indices[0]] = other_similarity


# 시각화
norm = mcolors.TwoSlopeNorm(vmin=0.6, vcenter=0.75, vmax=0.9)
plt.figure(figsize=(8, 8))
plt.imshow(confusion_matrix.cpu().detach().numpy(), cmap='Blues', interpolation='nearest', norm=norm)

# 첫 번째 클래스 영역에 테두리 추가
for i, j in zip(first_class_indices[0].cpu().detach().numpy(), first_class_indices[1].cpu().numpy()):
    rect = patches.Rectangle((j - 0.5, i - 0.5), 1, 1, linewidth=1, edgecolor='red', facecolor='none')
    plt.gca().add_patch(rect)
for i, j in zip(first_class_indices[1].cpu().detach().numpy(), first_class_indices[0].cpu().numpy()):
    rect = patches.Rectangle((j - 0.5, i - 0.5), 1, 1, linewidth=1, edgecolor='red', facecolor='none')
    plt.gca().add_patch(rect)


# 두 번째 클래스 영역에 테두리 추가
for i, j in zip(second_class_indices[0].cpu().detach().numpy(), second_class_indices[1].cpu().numpy()):
    rect = patches.Rectangle((j - 0.5, i - 0.5), 1, 1, linewidth=1.5, edgecolor='green', facecolor='none')
    plt.gca().add_patch(rect)
for i, j in zip(second_class_indices[1].cpu().detach().numpy(), second_class_indices[0].cpu().numpy()):
    rect = patches.Rectangle((j - 0.5, i - 0.5), 1, 1, linewidth=1.5, edgecolor='green', facecolor='none')
    plt.gca().add_patch(rect)


# Add color bar with labels
cbar = plt.colorbar()
cbar.set_label('Similarity', fontsize=12)

# Annotate matrix with values
for (i, j), val in np.ndenumerate(confusion_matrix.cpu().detach().numpy()):
    if val != 0:
        plt.text(j, i, f'{val:.2f}', ha='center', va='center', color='black', fontsize=8)

plt.title('Confusion Matrix with First and Second Class Similarity', fontsize=12, weight='bold')
plt.xlabel('Index', fontsize=14)
plt.ylabel('Index', fontsize=14)
plt.grid(False)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

norm = mcolors.TwoSlopeNorm(vmin=0.5, vcenter=0.65, vmax=0.8)
plt.imshow(sim_tar_mix.cpu().detach().numpy(), interpolation='nearest', cmap=plt.cm.Blues, norm=norm)
for (i, j), val in np.ndenumerate(sim_tar_mix.cpu().detach().numpy()):
    if val != 0:
        plt.text(j, i, f'{val:.2f}', ha='center', va='center', color='black', fontsize=8)
plt.colorbar()

plt.title('mix&target')
plt.xlabel('mix')
plt.ylabel('target')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

norm = mcolors.TwoSlopeNorm(vmin=0.2, vcenter=0.4, vmax=0.6)
plt.imshow(sim_mix_bias0.cpu().detach().numpy(), interpolation='nearest', cmap=plt.cm.Blues, norm=norm)
for (i, j), val in np.ndenumerate(sim_mix_bias0.cpu().detach().numpy()):
    if val != 0:
        plt.text(j, i, f'{val:.2f}', ha='center', va='center', color='black', fontsize=8)
plt.colorbar()

plt.title('mix&bias')
plt.xlabel('bias')
plt.ylabel('mix')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

norm = mcolors.TwoSlopeNorm(vmin=0.2, vcenter=0.3, vmax=0.4)
plt.imshow(sim_tar_bias0.cpu().detach().numpy(), interpolation='nearest', cmap=plt.cm.Blues, norm=norm)
for (i, j), val in np.ndenumerate(sim_tar_bias0.cpu().detach().numpy()):
    if val != 0:
        plt.text(j, i, f'{val:.2f}', ha='center', va='center', color='black', fontsize=8)
plt.colorbar()

plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
